# %% [markdown]
# CHECKING THE STATUS OF CAR INSURANCE CLAIM

# %% [markdown]
# Importing pandas and reading data

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\shubh\Downloads\archive (27)\Insurance claims data.csv")
df.head()
# Out:
#    policy_id  subscription_length  vehicle_age  customer_age region_code  \
# 0  POL045360                  9.3          1.2            41          C8
# 1  POL016745                  8.2          1.8            35          C2
# 2  POL007194                  9.5          0.2            44          C8
# 3  POL018146                  5.2          0.4            44         C10
# 4  POL049011                 10.1          1.0            56         C13
#
#    region_density segment model fuel_type     max_torque  ... is_brake_assist  \
# 0            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 1           27003      C1    M9    Diesel  200Nm@1750rpm  ...              No
# 2            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 3           73430       A    M1       CNG   60Nm@3500rpm  ...              No
# 4            5410      B2    M5    Diesel  200Nm@3000rpm  ...              No
#
# ...

# %%
#checking the null values
nv=df.isnull().sum()
nv[nv>0]
# Out:
# Series([], dtype: int64)

# %%
#checking the datatype
obj=df.dtypes
obj
# Out:
# policy_id                            object
# subscription_length                 float64
# vehicle_age                         float64
# customer_age                          int64
# region_code                          object
# region_density                        int64
# segment                              object
# model                                object
# fuel_type                            object
# max_torque                           object
# max_power                            object
# engine_type                          object
# airbags                               int64
# is_esc                               object
# is_adjustable_steering               object
# is_tpms                              object
# is_parking_sensors                   object
# is_parking_camera                    object
# rear_brakes_type                     object
# displacement                          int64
# cylinder                              int64
# ...

# %% [markdown]
# Checking the value counts of columns

# %%
df['model'].value_counts()
# Out:
# model
# M1     14948
# M4     14018
# M6     13776
# M8      4173
# M7      2940
# M3      2373
# M9      2114
# M5      1598
# M10     1209
# M2      1080
# M11      363
# Name: count, dtype: int64

# %%
df['region_code'].value_counts()
# Out:
# region_code
# C8     13654
# C2      7342
# C5      6979
# C3      6101
# C14     3660
# C13     3423
# C10     3155
# C9      2734
# C7      2167
# C12     1589
# C1      1468
# C11     1212
# C19      952
# C6       890
# C15      771
# C4       665
# C17      492
# C16      401
# C21      379
# C18      242
# C22      207
# C20      109
# Name: count, dtype: int64

# %%
df['segment'].value_counts()
# Out:
# segment
# B2         18314
# A          17321
# C2         14018
# B1          4173
# C1          3557
# Utility     1209
# Name: count, dtype: int64

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    20532
# CNG       20330
# Diesel    17730
# Name: count, dtype: int64

# %%
df['steering_type'].value_counts()
# Out:
# steering_type
# Power       33502
# Electric    23881
# Manual       1209
# Name: count, dtype: int64

# %%
#droping some columns which are of no use in predicition
df.drop('max_torque',axis=1,inplace=True)
df.drop('max_power',axis=1,inplace=True)
df.drop('engine_type',axis=1,inplace=True)
df.drop('policy_id',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    subscription_length  vehicle_age  customer_age region_code  region_density  \
# 0                  9.3          1.2            41          C8            8794
# 1                  8.2          1.8            35          C2           27003
#
#   segment model fuel_type  airbags is_esc  ... is_brake_assist  \
# 0      C2    M4    Diesel        6    Yes  ...             Yes
# 1      C1    M9    Diesel        2     No  ...              No
#
#   is_power_door_locks is_central_locking is_power_steering  \
# 0                 Yes                Yes               Yes
# 1                 Yes                Yes               Yes
#
#   is_driver_seat_height_adjustable  is_day_night_rear_view_mirror  is_ecw  \
# 0                              Yes                             No     Yes
# 1                              Yes                            Yes     Yes
#
#   is_speed_alert ncap_rating  claim_status
# 0            Yes           3             0
# ...

# %%
#checking datatypes 
obj1=df.dtypes
obj1
# Out:
# subscription_length                 float64
# vehicle_age                         float64
# customer_age                          int64
# region_code                          object
# region_density                        int64
# segment                              object
# model                                object
# fuel_type                            object
# airbags                               int64
# is_esc                               object
# is_adjustable_steering               object
# is_tpms                              object
# is_parking_sensors                   object
# is_parking_camera                    object
# rear_brakes_type                     object
# displacement                          int64
# cylinder                              int64
# transmission_type                    object
# steering_type                        object
# turning_radius                      float64
# length                                int64
# ...

# %%
#grouping 'object' datatype 
cat_col=obj1[obj1=='object']
print(cat_col)
# Out:
# region_code                         object
# segment                             object
# model                               object
# fuel_type                           object
# is_esc                              object
# is_adjustable_steering              object
# is_tpms                             object
# is_parking_sensors                  object
# is_parking_camera                   object
# rear_brakes_type                    object
# transmission_type                   object
# steering_type                       object
# is_front_fog_lights                 object
# is_rear_window_wiper                object
# is_rear_window_washer               object
# is_rear_window_defogger             object
# is_brake_assist                     object
# is_power_door_locks                 object
# is_central_locking                  object
# is_power_steering                   object
# is_driver_seat_height_adjustable    object
# is_day_night_rear_view_mirror       object
# ...

# %%
cat_columns=['region_code',
'segment',                             
'model',                               
'fuel_type',                           
'is_esc',                              
'is_adjustable_steering',              
'is_tpms',                             
'is_parking_sensors',                 
'is_parking_camera',                  
'rear_brakes_type',                   
'transmission_type',                   
'steering_type' ,                    
'is_front_fog_lights',                 
'is_rear_window_wiper',
'is_rear_window_washer',            
'is_rear_window_defogger',           
'is_brake_assist',                     
'is_power_door_locks',                 
'is_central_locking',               
'is_power_steering',                  
'is_driver_seat_height_adjustable',    
'is_day_night_rear_view_mirror',       
'is_ecw',                              
'is_speed_alert']

# %%
#changing the datatype of 'object'
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()



for i in cat_columns:
    df[i]=le.fit_transform(df[i])

# %%
#showing 2 row of dataframe
df.head(2)
# Out:
#    subscription_length  vehicle_age  customer_age  region_code  \
# 0                  9.3          1.2            41           20
# 1                  8.2          1.8            35           11
#
#    region_density  segment  model  fuel_type  airbags  is_esc  ...  \
# 0            8794        4      5          1        6       1  ...
# 1           27003        3     10          1        2       0  ...
#
#    is_brake_assist  is_power_door_locks  is_central_locking  \
# 0                1                    1                   1
# 1                0                    1                   1
#
#    is_power_steering  is_driver_seat_height_adjustable  \
# 0                  1                                 1
# 1                  1                                 1
#
#    is_day_night_rear_view_mirror  is_ecw  is_speed_alert  ncap_rating  \
# 0                              0       1               1            3
# 1                              1       1               1            4
#
# ...

# %%
#splitting the data into dependent and independent variable
x=df.drop('claim_status',axis=1)
y=df['claim_status']

# %%
#creating function to evaluate model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
def eval_model(ytest,ypred):
    print('classification_report\n',classification_report(ytest,ypred))
    print('confusion_matrix\n',confusion_matrix(ytest,ypred))
    print('accuracy_score\n',accuracy_score(ytest,ypred))

def mscore(model):
    print('Training score:',model.score(x_train,y_train))
    print('Testing score:',model.score(x_test,y_test))

# %%
#training and testing the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1)
print(len(x_train))
print(len(x_test))
# Out:
# 52732
# 5860

# %% [markdown]
# Building the model

# %% [markdown]
# KNeighbors

# %%
#kn neighbor
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
mscore(knn)
# Out:
# Training score: 0.9366987787301828
# Testing score: 0.9353242320819113

# %%
#predicting values
y_pred_knn=knn.predict(x_test)

# %%
eval_model(y_test,y_pred_knn)
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5494
#            1       0.07      0.00      0.01       366
#
#     accuracy                           0.94      5860
#    macro avg       0.50      0.50      0.49      5860
# weighted avg       0.88      0.94      0.91      5860
#
# confusion_matrix
#  [[5480   14]
#  [ 365    1]]
# accuracy_score
#  0.9353242320819113

# %% [markdown]
# Decision Tree

# %%
#decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
mscore(dt)
# Out:
# Training score: 0.9958848517029508
# Testing score: 0.8680887372013651

# %%
#predicting values
y_pred_dt=dt.predict(x_test)

# %%
eval_model(y_test,y_pred_dt)
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      5494
#            1       0.07      0.08      0.07       366
#
#     accuracy                           0.87      5860
#    macro avg       0.50      0.50      0.50      5860
# weighted avg       0.88      0.87      0.88      5860
#
# confusion_matrix
#  [[5056  438]
#  [ 335   31]]
# accuracy_score
#  0.8680887372013651

# %% [markdown]
# Random Forest

# %%
#random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=80,criterion='gini')
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=80)

# %%
mscore(rf)
# Out:
# Training score: 0.9956952135325798
# Testing score: 0.9281569965870308

# %%
#predicting values
y_pred_rf=rf.predict(x_test)

# %%
eval_model(y_test,y_pred_rf)
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      5494
#            1       0.03      0.01      0.01       366
#
#     accuracy                           0.93      5860
#    macro avg       0.49      0.50      0.49      5860
# weighted avg       0.88      0.93      0.90      5860
#
# confusion_matrix
#  [[5437   57]
#  [ 364    2]]
# accuracy_score
#  0.9281569965870308

# %% [markdown]
# To find which model is best fitted, we can make a dataframe to get the detail at one place

# %%
Pred={'KNN':accuracy_score(y_test,y_pred_knn),
      'DTree':accuracy_score(y_test,y_pred_dt),
      'RForest':accuracy_score(y_test,y_pred_rf)}
result=pd.DataFrame(Pred,index=['Accuarcy'])
result.T
# Out:
#          Accuarcy
# KNN      0.935324
# DTree    0.868089
# RForest  0.928157

# %% [markdown]
# From above data we can conclude that KNN is the best model
